# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/repos-especializacion-UdeA/fundamendos-de-programacion-DS/blob/main/pruebas/Prueba_1.ipynb)

# %% [markdown]
# # **Prueba \#1**
#
# En la siguiente pureba se evalua de manera EXCLUSIVA lo que se solicita, cualquier otra respuesta adicional a ella será valorada, más no evaluada. Entregue la prueba en un repositorio de github, o en el classroom antes de el lunes 12 de Agosto a las 00:00:00 hora colombiana.
#
# **Incluya como encabezado los nombres de los participantes y las cédulas**

# %% [markdown]
# ## **Ejercicio 1** (50 pts)
#
# Escriba una clase `Pedido` que pueda ser usada para gestionar la información de los pedidos realizados a una pastelería (o carnicería o tienda de ropa o empresa que ud desee). Evite usar módulos como numpy, pandas o cualquier otro.
#
# ### **Rubrica**:
#
# 1. Generación de la clase que funcione correctamente con al menos 2 métodos y 2 atributos. **30 pts**.
# 2. Comentarios y  documentación que sirva para quien deba usar la clase. **5 pts**.
# 3. Pertinencia de la clase en el ámbito, ¿Por qué será útil esta herramienta y cómo ayudará a mejorar el negocio? esta será entregada en una celda de texto. **10 pts**.
# 4. ¿Cree que se pueda construir una clase hija que ayude al proceso? Si sí constrúyala, sino, argumente por qué en una célda de texto. **5 pts**.

# %% [markdown]
# ## **Ejercicio 2** (50 pts)
#
# Realice los siguientes ejercicios con numpy
#
# 1. Resolver el siguiente sistema de ecuaciones. **14 pts**
#
# $$
# 2x + 3y - z + 4w + 5v = 15
# $$
#
# $$
# x - 2y + 4z - 3w + v = 6
# $$
#
# $$
# 3x + 2y - 3z + 5w - 2v = 11
# $$
#
# $$
# 4x + y - 2z + 3w + 2v = 8
# $$
#
# $$
# x + y + z + w + v = 7
# $$
#
# 2. Calcule el valor del número de Euler o constante de Napier $e = 2,71828$ como:
#
# $$e = \sum_i ^{\infty} \frac{1}{n!}$$
#
#   ¿Qué precisión en términos de el número de términos necesita para dar cuenta de los primeros 5 números de la coma decimal? **20 pts**
#
#   **Remark**: Requerirá de algo de creatividad para calcular el factorial sin el uso de ciclos for ni recursividad, siéntase libre de buscar en internet, sin embargo recuerde tratar que su cálculo sea vectorizado.
#
# 3. Ecuentre los auto valores y auto vectores de la matriz.  **16 pts**
#
# $$
# \begin{pmatrix}
# 2 & 1 & 1 \\
# 4 & 3 & 2 \\
# 1 & 1 & 2 \\
# \end{pmatrix}
# $$

# %%
import numpy as np

# %%
m = np.array([[2, 3, -1, 4, 5],
              [1, -2, 4, -3, 1],
              [3, 2, -3, 5, -2],
              [4, 1, -2, 3, 2],
              [1, 1, 1, 1, 1]])

v = np.array([15, 6, 11, 8, 7])

x = np.linalg.solve(m, v)
x
# Out:
# array([-1.67741935, -7.87096774,  5.12903226, 10.        ,  1.41935484])

# %%
from scipy import special

# Calcular el factorial de un número usando SciPy
n = 5
factorial_sp = special.factorial(n, exact=True)
print(f"El factorial de {n} es {factorial_sp}")
# Out:
# El factorial de 5 es 120

# %%
def nap(n):
  return np.sum(1/special.factorial(i, exact=True) for i in range(n+1))

nap(9)
# Out:
# <ipython-input-5-c571c892f50b>:2: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return np.sum(1/special.factorial(i, exact=True) for i in range(n+1))
# 2.7182815255731922

# %%
import numpy as np

# Calcular el factorial de un número usando NumPy
n = 5
factorial_np = np.math.factorial(n)

print(f"Factorial de {n} usando NumPy: {factorial_np}")
# Out:
# Factorial de 5 usando NumPy: 120
# <ipython-input-6-9ff27e4f260d>:5: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   factorial_np = np.math.factorial(n)

# %%
def factorial(n):
  if n == 0:
    return 1
  else:
    return n * factorial(n-1)

factorial(5)

# %%
x = np.array([[2, 1, 1],
                [4, 3, 2],
                [1, 1, 2]])


np.linalg.eig(x)
# Out:
# EigResult(eigenvalues=array([5.44948974, 0.55051026, 1.        ]), eigenvectors=array([[ 3.53553391e-01,  3.53553391e-01,  6.66133815e-16],
#        [ 8.66025404e-01, -8.66025404e-01, -7.07106781e-01],
#        [ 3.53553391e-01,  3.53553391e-01,  7.07106781e-01]]))
